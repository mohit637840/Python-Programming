# %% [markdown]
# ### Class Relationships
#
# - Aggregation
# - Inheritance

# %% [markdown]
# ### Aggregation(Has-A relationship):
# eg: customer has a address
#
# eg: Restaurent has a Menu

# %%
#example
class Customer:
    def __init__(self,name,gender,address):
        self.name=name
        self.gender=gender
        self.address=address
    def Print_address(self):
        print(self.address.city,self.address.state,self.address.pin)
# there are so many things inside address entity for eg pincode,city etc
# so we make an address class
class Address:
    def __init__(self,city,state,pin):  
        self.city=city
        self.pin=pin
        self.state=state
addr1=Address('kota','Rajasthan',324001)
cust=Customer('Mohit Singh','Male',addr1)
cust.Print_address()
# Out:
# kota Rajasthan 324001

# %%
#example --> city can not print
class Customer:
    def __init__(self,name,gender,address):
        self.name=name
        self.gender=gender
        self.address=address
    def Print_address(self):
        print(self.address.__city,self.address.state,self.address.pin)
# there are so many things inside address entity for eg pincode,city etc
# so we make an address class
class Address:
    def __init__(self,city,state,pin):  
        self.city=__city
        self.pin=pin
        self.state=state
addr1=Address('kota','Rajasthan',324001)
cust=Customer('Mohit Singh','Male',addr1)
cust.Print_address()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 16
#      12     def __init__(self,city,state,pin):
#      13         self.city=__city
#      14         self.pin=pin
#      15         self.state=state
# ---> 16 addr1=Address('kota','Rajasthan',324001)
#      17 cust=Customer('Mohit Singh','Male',addr1)
#      18 cust.Print_address()
#
# Cell In[5], line 13, in Address.__init__(self, city, state, pin)
#      12     def __init__(self,city,state,pin):
# ---> 13         self.city=__city
#      14         self.pin=pin
#      15         self.state=state
#
# NameError: name '_Address__city' is not defined

# %%
#example --> city can not print
class Customer:
    def __init__(self,name,gender,address):
        self.name=name
        self.gender=gender
        self.address=address
    def Print_address(self):
        print(self.address.get_city(),self.address.state,self.address.pin)
    def edit_profile(self,new_name,new_address,new_city,new_state,new_pin):
        self.name=new_name
        self.address.edit_address(new_city,new_state,new_pin)
        # self.Print_address()

# there are so many things inside address entity for eg pincode,city etc
# so we make an address class
class Address:
    def __init__(self,city,state,pin):  
        self.__city=city
        self.pin=pin
        self.state=state
    def get_city(self):
        return self.__city
    def edit_address(self,new_city,new_state,new_pin):
        self.__city=new_city
        self.states=new_state
        self.pin=new_pin


addr1=Address('kota','Rajasthan',324001)
cust=Customer('Mohit Singh','Male',addr1)
cust.Print_address()
cust.edit_profile("Ajay","Barkheda","Bharatpur","Rajasthan",321028)
cust.Print_address()
# Out:
# kota Rajasthan 324001
# Bharatpur Rajasthan 321028

# %%
#example --> city can not print
class Customer:
    def __init__(self,name,gender,address):
        self.name=name
        self.gender=gender
        self.address=address
    def Print_address(self):
        print(self.address._Address__city,self.address.state,self.address.pin)
# there are so many things inside address entity for eg pincode,city etc
# so we make an address class
class Address:
    def __init__(self,city,state,pin):  
        self.__city=city
        self.pin=pin
        self.state=state
    # def get_city(self):
    #     return self.__city
addr1=Address('kota','Rajasthan',324001)
cust=Customer('Mohit Singh','Male',addr1)
cust.Print_address()
# Out:
# kota Rajasthan 324001

# %% [markdown]
# ##### Aggregation class diagram

# %% [markdown]
# ![alt text](c9b5ac5c-a391-4560-9069-77340eeb11d6.png)

# %% [markdown]
# ### Inheritance
#
# - What is inheritance (jo apke pitashree ka hai vo apka haii)
# - Example
# - What gets inherited?

# %%
# Inheritance and it's benefits
# Code Reusability

# %%
# Udemy:>
# student                Teacher
# - Login               - login
# - register            - register  
# - enroll              - create
# - review              - reply

# instead of creating 2 classes and writing long code we will make 3 classes :
# user(login,register) ----> Student (enroll,review)
#                      ----> Teacher (create,reply)

# %%
# Example :
#Parent
class user:
    def __init__(self):
        self.name='Mohit'
    def login(self):
        print("Login!")

#child 
class Student(user): 
    #agar yahan constructor daal dete hain and to if calling with child class object 
    def enroll(self):
        print("Enroll into the course")

std1=Student()
std1.enroll()
std1.name
user1=user()
user1.login()
# Out:
# Enroll into the course
# Login!

# %%
# Class diagram
# agar rhombus ho to aggregation 
# agar traingle ho to inheritance (arrow ka head parent ki taraf hota hai)

# %% [markdown]
# ##### What gets inherited?
#
# - Constructor
# - Non Private Attributes
# - Non Private Methods

# %%
# constructor example

class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    pass

s=SmartPhone(20000, "Apple", 13)
s.buy()
# Out:
# Inside phone constructor
# Buying a phone

# %%
# constructor example 2

class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

class SmartPhone(Phone):
    def __init__(self, os, ram):
        self.os = os
        self.ram = ram
        print ("Inside SmartPhone constructor")

s=SmartPhone("Android", 2)
s.brand
# Out:
# Inside SmartPhone constructor
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 17
#      13         self.ram = ram
#      14         print ("Inside SmartPhone constructor")
#      15
#      16 s=SmartPhone("Android", 2)
# ---> 17 s.brand
#
# AttributeError: 'SmartPhone' object has no attribute 'brand'

# %%
# child can't access private members of the class
# apke papa ka agar swiz bank main kala dhan hai uhh can not acess that. 

class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    #getter
    def show(self):
        print (self.__price)

class SmartPhone(Phone):
    def check(self):
        print(self.__price)

s=SmartPhone(20000, "Apple", 13)
s.show()
# Out:
# Inside phone constructor
# 20000

# %%
class Parent:

    def __init__(self,num):
        self.__num=num

    def get_num(self):
        return self.__num

class Child(Parent):

    def show(self):
        print("This is in child class")

son=Child(100) #constructor called --> child ka hai nahi so parent ka hoga
print(son.get_num())
son.show()
# Out:
# 100
# This is in child class

# %%
class Parent:

    def __init__(self,num):
        self.__num=num

    def get_num(self):
        return self.__num

class Child(Parent):

    def __init__(self,val,num): #val=100,num=10
        self.__val=val

    def get_val(self):
        return self.__val

son=Child(100,10)
# print("Parent: Num:",son.get_num())
print("Child: Val:",son.get_val())
# Out:
# Child: Val: 100

# %%
class A:
    def __init__(self):
        self.var1=100

    def display1(self,var1):
        print("class A :", self.var1)
class B(A):

    def display2(self,var1):
        print("class B :", self.var1)

obj=B()
obj.display1(200)
# Out:
# class A : 100

# %%
# Method Overriding
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    def buy(self): #child class overrides on parent class methods
        
        print ("Buying a smartphone")

s=SmartPhone(20000, "Apple", 13)

s.buy()
# Out:
# Inside phone constructor
# Buying a smartphone

# %% [markdown]
# ### Super Keyword

# %%
#syntax to call parent ka buy method 
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera
A
    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    def buy(self):
        print ("Buying a smartphone")
        # syntax to call parent ka buy method
        super().buy()

s=SmartPhone(20000, "Apple", 13)
s.buy()
# Out:
# Inside phone constructor
# Buying a smartphone
# Buying a phone

# %%
class Phone:
    def __init__(self,price,brand,camera):
        self.price=price
        self.brand=brand
        self.camera=camera
    
class Smartphone(Phone):
    def __init__(self,price,brand,camera,os,ram):
        print("inside smartphone constructor")
        super().__init__(price,brand,camera) #self nhi jayega inside it
        self.os=os
        self.ram=ram

s=Smartphone(25000,"Apple",12,"ios","16gb")
print(s.os)
print(s.ram)
# Out:
# inside smartphone constructor
# ios
# 16gb

# %%
#super keyword class ke inside use khota hai it can not be used outside class
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera
    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    def buy(self):
        print ("Buying a smartphone")
        print(super().brand) # can not print the variables or attributes
        # syntax to call parent ka buy method
s=SmartPhone(20000, "Apple", 13)
s.super().buy() #class
# Out:
# Inside phone constructor

# %%
#super can not acess variable
#super can not be used outside class
#super can acess only methods not attributes
#super is used inside child class

# %% [markdown]
# ##### Inheritance in summary
#
# - A class can inherit from another class.
#
# - Inheritance improves code reuse
#
# - Constructor, attributes, methods get inherited to the child class
#
# - The parent has no access to the child class
#
# - Private properties of parent are not accessible directly in child class
#
# - Child class can override the attributes or methods. This is called method overriding
#
# - super() is an inbuilt function which is used to invoke the parent class methods and constructor

# %%
class Parent:

    def __init__(self,num):
      self.__num=num

    def get_num(self):
      return self.__num

class Child(Parent):

    def __init__(self,num,val): #num=100,val=200
      super().__init__(num)
      self.__val=val

    def get_val(self):
      return self.__val

son=Child(100,200)
print(son.get_num())
print(son.get_val())
# Out:
# 100
# 200

# %%
class Parent:
    def __init__(self):
        self.num=100

class Child(Parent):

    def __init__(self):
        super().__init__()
        self.var=200

    def show(self):
        print(self.num)
        print(self.var)

son=Child()
son.show()
# Out:
# 100
# 200

# %%
class Parent:
    def __init__(self):
        self.__num=100

    def show(self):
        print("Parent:",self.__num)

class Child(Parent):
    def __init__(self):
        super().__init__() #sel.__num=100
        self.__var=10

    def show(self):
        print("Child:",self.__var)

obj=Child()
obj.show()
# Out:
# Child: 10

# %%
class Parent:
    def __init__(self):
        self.__num=100

    def show(self):
        print("Parent:",self.__num)

class Child(Parent):
    def __init__(self):
        super().__init__()
        self.__var=10

    def show(self):
        print("Child:",self.__var)

obj=Child()
obj.show()
# Out:
# Child: 10

# %% [markdown]
# ### Types of Inheritance
#
# - Single Inheritance
# - Multilevel Inheritance
# - Hierarchical Inheritance
# - Multiple Inheritance(Diamond Problem)
# - Hybrid Inheritance

# %% [markdown]
# ![alt text](1_gvHEf4lT2m_dHyH6c0UC1Q.png)

# %%
# single inheritance
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    pass

SmartPhone(1000,"Apple","13px").buy()
# Out:
# Inside phone constructor
# Buying a phone

# %%
# multilevel
class Product:
    def review(self):
        print ("Product customer review")

class Phone(Product):
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    pass

s=SmartPhone(20000, "Apple", 12)

s.buy()
s.review()
# Out:
# Inside phone constructor
# Buying a phone
# Product customer review

# %%
# Hierarchical
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    pass

class FeaturePhone(Phone):
    pass

SmartPhone(1000,"Apple","13px").buy()
FeaturePhone(10,"Lava","1px").buy()
# Out:
# Inside phone constructor
# Buying a phone
# Inside phone constructor
# Buying a phone

# %%
# Multiple
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class Product:
    def review(self):
        print ("Customer review")

class SmartPhone(Phone, Product):
    pass

s=SmartPhone(20000, "Apple", 12)

s.buy()
s.review()
# Out:
# Inside phone constructor
# Buying a phone
# Customer review

# %%
# the diamond problem
# https://stackoverflow.com/questions/56361048/what-is-the-diamond-problem-in-python-and-why-its-not-appear-in-python2
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class Product:
    def buy(self):
        print ("Product buy method")

# Method resolution order
class SmartPhone(Phone,Product): #jisko hamne pehle inherit kiya uski baat mani jayegi
    pass

s=SmartPhone(20000, "Apple", 12)

s.buy()
# Out:
# Inside phone constructor
# Buying a phone

# %%
# the diamond problem
# https://stackoverflow.com/questions/56361048/what-is-the-diamond-problem-in-python-and-why-its-not-appear-in-python2
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class Product:
    def buy(self):
        print ("Product buy method")

# Method resolution order
class SmartPhone(Product,Phone): #jisko hamne pehle inherit kiya uski baat mani jayegi
    pass

s=SmartPhone(20000, "Apple", 12)

s.buy()
# Out:
# Inside phone constructor
# Product buy method

# %%
class A:

    def m1(self):
        return 20

class B(A):

    def m1(self):
        return 30

    def m2(self):
        return 40

class C(B): # B ko inherit kiya hai so usi ke method ko use karenge 

    def m2(self):
        return 20
obj1=A()
obj2=B()
obj3=C()
print(obj1.m1() + obj3.m1()+ obj3.m2())
# Out:
# 70

# %%
class A:

    def m1(self):
        return 20

class B(A):

    def m1(self):
        val=super().m1()+30
        return val

class C(B):

    def m1(self):
        val=self.m1()+20
        return val
obj=C()
print(obj.m1())
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-56-bb3659d52487> in <module>
#      16         return val
#      17 obj=C()
# ---> 18 print(obj.m1())
#
# <ipython-input-56-bb3659d52487> in m1(self)
#      13
#      14     def m1(self):
# ---> 15         val=self.m1()+20
#      16         return val
#      17 obj=C()
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-56-bb3659d52487> in m1(self)
#      13
#      14     def m1(self):
# ---> 15         val=self.m1()+20
#      16         return val
#      17 obj=C()
#
# RecursionError: maximum recursion depth exceeded

# %% [markdown]
# ### Polymorphism :
# same chiz situation ke hisab se alag alag behave kare
#
# - Method Overriding
# - Method Overloading
# - Operator Overloading

# %%
#python main method overloading nhi hota java and c++ main hota hai
class shape:
    def area(self,radius):
        return 3.14*radius*radius
    
    def area(self,length,breadth):
        return length*breadth
s=shape()
print(s.area(2))
print(s.area(3,4))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 9
#       5
#       6     def area(self,length,breadth):
#       7         return length*breadth
#       8 s=shape()
# ----> 9 print(s.area(2))
#      10 print(s.area(3,4))
#
# TypeError: shape.area() missing 1 required positional argument: 'breadth'

# %%
class Shape:

  def area(self,a,b=0):
    if b == 0:
      return 3.14*a*a
    else:
      return a*b

s = Shape()

print(s.area(2))
print(s.area(3,4))
# Out:
# 12.56
# 12

# %%
'hello' + 'world' #concat
# Out:
# 'helloworld'

# %%
4 + 5 #addition
# Out:
# 9

# %%
[1,2,3] + [4,5] #merging
# Out:
# [1, 2, 3, 4, 5]

# %%
# we made fraction objects and add those with add magic operator

# %% [markdown]
# ### Abstraction
# Hidden or chupa hua
# eg:our laptop and it has many components and we just care about them at surface level. so laptop is abstracted.

# %%
# aap as a senier developer apne lower classes ke upar constraints apply kar sakte ho
#unhain majboor kar sakte ho for maitaining code

# %%
# Abstract class : which have atleast one abstract method 
# Abstract Method : jiske andar kuch bhi code nhi likha hota 
# Concrete Method: jiske andar code likha hota hai 
from abc import ABC,abstractmethod
class BankApp(ABC):
    def database(self):
        print("connected to database")
    
    @abstractmethod
    def security(self): #abstract class khali because maybe windows different security
        #use karega ios alag use karega etc so we keep this empty..
        pass
    @abstractmethod
    def display(self): 
        pass

# %%
class MobileApp(BankApp):
    def Mobile_login(self):
        print("login to mobile")

    def security(self):
        print("Mobile Security")
    
    def display(self):
        print("Mobile Display")

# %%
mob=MobileApp()
mob.database()
mob.display()
# Out:
# connected to database
# Mobile Display

# %%
#abstract class ka object nhi bana sakte 
abs=BankApp()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 2
#       1 #abstract class ka object nhi bana sakte
# ----> 2 abs=BankApp()
#
# TypeError: Can't instantiate abstract class BankApp without an implementation for abstract method 'security'
